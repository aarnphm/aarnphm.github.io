# %% [markdown]
# ### Static vs Dynamic Binding

# %% [markdown]
# Explain the difference between static and dynamic binding!

# %% [markdown]
# 1. Explain dynamic binding of functions and variables in Python and give examples!

# %% [markdown]
# _Answer_: In Python, functions are dynamically bound. The call to `f()` in `g()` below is not resolved to the definition of `f` that is valid when `g` is compiled, but when `g` is executed. In Python, the declaration of a function is just an assignment of the function body to a variable, the function name. The value of a variable is looked up at execution, which leads to dynamic binding of functions:

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# 2. Explain the dynamic and static binding of fields and methods in Java and give examples!

# %% [markdown]
# YOUR ANSWER HERE

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# 3. Dynamic binding can, in general, more easily lead to errors, as the textually closest definition may not be the one that is taken when executing. To make programming safer, Python binds differently when scopes are involved. Explain with the examples below how dynamic binding in Python works! What is the algorithm for resolving functions, or variables in general?

# %%
def f(): return 5
e = f
def g(): return f()
def f(): return 7
e(), g()

# %%
def f(): return 5
def g(): return f()
def h():
    def f(): return 7
    return g(), f()
h()

# %%
def f(): return y
def g(): y = 3; return f()
g()

# %%
x = 1
def f(): return x
def g(): x = 3; return f() + x
x = 2
g()

# %% [markdown]
# YOUR ANSWER HERE
