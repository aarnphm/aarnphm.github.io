# %% [markdown]
# #### LL and LR Grammars

# %% [markdown]
# Which of the following grammars is `LL(1)`, `LR(0)`, `LR(1)`? Give brief explanations!

# %% [markdown]
# 1.
# ```
# S → a X d | b
# X → c | ε
# ```

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 2.
# ```
# S → a X | b
# X → c | d
# ```

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 3.
# ```
# E → E + id | id
# ```

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 4.
# ```
# S → a A | a B
# A → c
# B → d
# ```

# %% [markdown]
# YOUR ANSWER HERE
